# %% [markdown]
# # 🐍 Día 1: Fundamentos de Python y Lógica
#
# ¡Bienvenidos! Hoy comenzaremos a hablar el idioma de las máquinas.
#
# **Objetivos de hoy:**
# 1.  Hacer que la computadora hable (`print`).
# 2.  Guardar información en la memoria (`variables`).
# 3.  Pedirle datos al usuario (`input`).
# 4.  Tomar decisiones lógicas (`if/else`).

# %% [markdown]
# ---

# %% [markdown]
# ## 1. La Salida: `print()`
#
# La función `print` sirve para mostrar información en la pantalla. Es la forma en que el programa se comunica con nosotros.

# %%
# Esto es un comentario: Python ignora lo que escribas después del '#'
# Presiona 'Play' o Shift+Enter para ejecutar este bloque

print("¡Hola Mundo! Estoy programando en Python.")
print("Puedo escribir múltiples líneas.")
# Out:
# ¡Hola Mundo! Estoy programando en Python.
# Puedo escribir múltiples líneas.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Variables (Cajas de memoria)
#
# Una variable es como una **caja** donde guardamos un dato y le ponemos una etiqueta (nombre) para encontrarlo después.
#
# Existen varios tipos de datos básicos:
# * **String (Texto):** Va entre comillas `"Hola"`.
# * **Int (Entero):** Números sin coma `10`.
# * **Float (Flotante):** Números con coma `10.5`.

# %%
# Creando variables
nombre_alumno = "Juan"
edad = 25
altura = 1.75
es_estudiante = True  # Esto es un Booleano (Verdadero/Falso)
print("Variables creadas.")
print(type(nombre_alumno))  # Tipo de dato: str (cadena de texto)
print(type(edad))           # Tipo de dato: int (entero)
print(type(altura))        # Tipo de dato: float (número decimal)           
print(type(es_estudiante))  # Tipo de dato: bool (booleano)     

# Usando las variables

print("Nombre:", nombre_alumno)
print("Edad:", edad)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. La Entrada: `input()`
#
# Hasta ahora, nosotros escribimos los datos en el código. Pero, ¿y si queremos preguntarle algo al usuario?
#
# Usamos `input()`. **OJO:** `input` siempre devuelve texto (string). Si queremos números, hay que convertirlo con `int()`.

# %%
# Preguntando nombre
tu_nombre = input("¿Cómo te llamas? ")
print("¡Hola " + tu_nombre + "! Gusto en conocerte.")

# %%
# Preguntando un número (Conversión necesaria)
edad_texto = input("¿Cuántos años tienes? ")
edad_numero = int(edad_texto)  # Convertimos texto a número

# Ahora podemos hacer matemáticas
edad_futura = edad_numero + 10
print("En 10 años tendrás:", edad_futura)

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Lógica y Decisiones: `if / else`
#
# Los programas no son lineales. A veces tienen que tomar caminos diferentes dependiendo de los datos. Para eso usamos:
#
# * `if` (Si pasa esto...)
# * `else` (Si no...)
# * `elif` (Sino, si pasa esto otro...)
#
# **Importante:** ¡La identación (sangría/espacio) es vital en Python!

# %%
temperatura = 35

if temperatura > 30:
    print("🔥 ¡Hace mucho calor! Prende el ventilador.")
elif temperatura < 10:
    print("❄️ ¡Hace frío! Ponte abrigo.")
else:
    print("☁️ El clima está agradable.")

# %% [markdown]
# ---

# %% [markdown]
# ## 🏆 Ejercicio Práctico: Calculadora de Edad
#
# **Consigna:**
# 1. Crea un programa que le pregunte al usuario su **año de nacimiento**.
# 2. Calcula automáticamente cuántos años tiene (basado en el año actual, por ejemplo, 2025).
# 3. Usa un condicional `if`:
#     * Si es mayor o igual a 18 años, imprime: **"Eres mayor de edad, puedes pasar."**
#     * Si es menor de 18 años, imprime: **"Eres menor, acceso denegado."**

# %%
# Escribe tu código aquí debajo 👇

# 1. Definir año actual
anio_actual = 2025

# 2. Pedir año de nacimiento (recuerda convertir a int)


# 3. Calcular edad


# 4. Condicional If / Else

# %% [markdown]
# ---

# %% [markdown]
# ## 🚀 Más Ejercicios Prácticos
#
# ¡Sigue practicando para dominar estos conceptos!

# %% [markdown]
# ### 1. Calculadora de Propinas
#
# **Consigna:**
# 1. Pide al usuario el **total de la cuenta** (puede tener decimales).
# 2. Pide el **porcentaje de propina** que quiere dejar (ej. 10, 15, 20).
# 3. Calcula el monto de la propina y el total a pagar.
# 4. Muestra ambos valores en pantalla.

# %%
# Tu código aquí 👇
while True:
    try:
        total_cuenta= float(input("ingrese el total de su cuenta"))
        porcentaje_propina= float(input("ingrese el porcentaje de la propina que desea dejar"))
        total_a_pagar= total_cuenta + ((total_cuenta*porcentaje_propina)/100)
        print(total_cuenta ,"$") 
        print(porcentaje_propina ,"%")
        print(f"deberas pagar  {total_a_pagar} $")
        break
    except ValueError: 
        print("error, ingrese un numero")
    except ZeroDivisionError:
      print("error no se puede dividir por 0")
# Out:
# 100 $
# 10 %
# deberas pagar  110.0 $

# %% [markdown]
# ### 2. ¿Par o Impar?
#
# **Consigna:**
# 1. Pide al usuario un **número entero**.
# 2. Usa el operador módulo `%` para saber si es divisible por 2.
# 3. Si el resto es 0, imprime "Es par". Si no, "Es impar".

# %%
# Tu código aquí 👇
while True:
    try:
        numero= int(input("ingrese un numero"))
        if numero%2==0:
            print("tu numero es par") 
        else:
            print ("tu numero es impar")
        break
    except ValueError:
        print("pone numero")
# Out:
# tu numero es par

# %% [markdown]
# ### 3. Conversor de Monedas
#
# **Consigna:**
# 1. Define una variable con el **tipo de cambio** (ej. 1 dólar = 1000 pesos).
# 2. Pide al usuario una cantidad en **dólares**.
# 3. Calcula cuánto sería en **pesos**.
# 4. Muestra el resultado.

# %%
# Tu código aquí 👇
while True:
    try:    
        cant_dolar= float(input("ingrese su cantidad en dolares"))
        cambio_dolarpesos = cant_dolar*1500
        print(f"tenes {cambio_dolarpesos} pesos")
        break
    except ValueError:
        print("error, ingrese un numero")
# Out:
# tenes 8400.0 pesos

# %% [markdown]
# ### 4. Área del Rectángulo
#
# **Consigna:**
# 1. Pide al usuario la **base** del rectángulo.
# 2. Pide al usuario la **altura** del rectángulo.
# 3. Calcula el área (base * altura).
# 4. Muestra el resultado.

# %%
# Tu código aquí 👇
while True:
    try:
        altr= float(input("ingrese la altura del rectangulo"))
        basr= float(input("ingrese la base del rectangulo"))
        ar = altr*basr
        print(f"la altura es {altr}")
        print(f"la base es {basr}")
        print(f"su area es {ar}")
        break
    except ValueError:
        print("error, ingrese un numero")
# Out:
# error, ingrese un numero
# error, ingrese un numero
# la altura es 59.0
# la base es 565.0
# su area es 33335.0

# %% [markdown]
# ### 5. Promedio de 3 Notas
#
# **Consigna:**
# 1. Pide al usuario **3 notas** (pueden ser decimales).
# 2. Calcula el promedio (suma de las 3 notas dividido 3).
# 3. Muestra el promedio final.

# %%
# Tu código aquí 👇
while True:
    try:
        nota1= float(input("ingrese su primer nota"))
        nota2= float(input("ingrese su segunda nota"))
        nota3= float(input("ingrese su tercer nota"))
        prom= (nota1+nota2+nota3)/3.0
        print (f"su promedio es {prom}")
        break
    except ValueError:
        print("error, ingrese un num")
# Out:
# error, ingrese un num
# su promedio es 5.0

# %% [markdown]
# ### 6. Conversor Celsius a Fahrenheit
#
# **Consigna:**
# 1. Pide la temperatura en **grados Celsius**.
# 2. Aplica la fórmula: `(Celsius * 9/5) + 32`.
# 3. Muestra la temperatura en **Fahrenheit**.

# %%
# Tu código aquí 👇
while True:
    try:
        cel=float(input("ingrese la temperatura en grados celsius"))
        far=((cel*9/5)+32)
        print(f"la conversion es {far} farenheit")
        break
    except ValueError:
        print("error pone un numero")
# Out:
# error pone un numero
# la conversion es 852.8 farenheit

# %% [markdown]
# ### 7. Calculadora de Salario
#
# **Consigna:**
# 1. Pide las **horas trabajadas** en el mes.
# 2. Pide la **tarifa por hora**.
# 3. Calcula el salario total (horas * tarifa).
# 4. Muestra el resultado.

# %%
# Tu código aquí 👇
while True:
    try:
        ht= float(input("ingrese sus horas trabajadas"))
        tph= float(input("ingrse su tarifapor hora"))
        sal_total= (ht*tph)
        print(f"su salario es {sal_total}")
        break
    except ValueError:
        print("error, ingrese numero")
# Out:
# error, ingrese numero
# su salario es 5610.0

# %% [markdown]
# ### 8. Conversor de Días a Segundos
#
# **Consigna:**
# 1. Pide una cantidad de **días**.
# 2. Calcula cuántos segundos son (días * 24 * 60 * 60).
# 3. Muestra el resultado.

# %%
# Tu código aquí 👇
while True:
    try:
        di=int(input("ingrese el numero de dias para la conversion"))
        conv=(di*24*60*60)
        print(f"son {conv} segundos")
        break
    except ValueError:
        print("error, ingrese un numero")
# Out:
# son 31536000 segundos

# %% [markdown]
# ### 9. Calculadora de Descuento
#
# **Consigna:**
# 1. Pide el **precio original** de un producto.
# 2. Pide el **porcentaje de descuento** (ej. 20).
# 3. Calcula el monto descontado y el precio final.
# 4. Muestra ambos.

# %%
# Tu código aquí 👇
po= float(input("ingrese preciooriginal"))
pd= float(input("ingrese porcentaje de descuento"))
md= (po*pd)/100
pf= po-md
print(f"usted se ahorro {md}")
print(f"su precio final es {pf}")
# Out:
# usted se ahorro 100.0
# su precio final es 900.0

# %% [markdown]
# ### 10. División Segura
#
# **Consigna:**
# 1. Pide **dos números** al usuario.
# 2. Si el segundo número es 0, imprime **"Error: No se puede dividir por cero"**.
# 3. Si no, realiza la división y muestra el resultado.

# %%
# Tu código aquí 👇
while True:
    try:
        num1=float(input("ingrese un numero"))
        num2=float(input("ingrese un segundo numero"))
        if num2==0:
            print("Error:no se puede dividir por cero")
        else:
            div=num1/num2
            print(f"su numero es {div}")
        break
    except ValueError:
        print("error, ingrese un numero")
# Out:
# error, ingrese un numero
# error, ingrese un numero
# error, ingrese un numero
# su numero es 3.2486118122160526

# %% [markdown]
# ### 11. Mayor de Dos Números
#
# **Consigna:**
# 1. Pide **dos números** diferentes.
# 2. Usa `if/else` para determinar cuál es mayor.
# 3. Imprime **"El mayor es: [número]"**.

# %%
# Tu código aquí 👇
while True:
    try:
        num1=float(input("ingrese un numero"))
        num2=float(input("ingrese un segundo numero"))
        if num1>num2:
            print(f"numero {num1} es mayor")
        elif num1==num2:
            print("los numeros son iguales")
        else:
            print(f"el numero {num2} es mayor")
        break
    except ValueError:
        print("error, ingrese un numero")
# Out:
# los numeros son iguales

# %% [markdown]
# ### 12. Positivo, Negativo o Cero
#
# **Consigna:**
# 1. Pide un **número**.
# 2. Usa `if/elif/else`.
# 3. Si es mayor a 0 -> "Positivo".
# 4. Si es menor a 0 -> "Negativo".
# 5. Si es 0 -> "Cero".

# %%
# Tu código aquí 👇
while True:
    try:
        num1=float(input("ingrese su numero"))
        if num1>0:
            print(f"su numero es positivo")
        elif num1<0:
            print(f"su numero es negativo")
        else: 
            print(F"su numero es 0")
        break
    except ValueError:
        print("error, ingrese un numero")
# Out:
# error, ingrese un numero
# su numero es positivo

# %% [markdown]
# ### 13. Aprobado o Reprobado
#
# **Consigna:**
# 1. Pide la **nota** de un examen (0-10).
# 2. Si la nota es mayor o igual a 6, imprime **"Aprobado"**.
# 3. Si no, imprime **"Reprobado"**.

# %%
# Tu código aquí 👇
while True:
    try:
        nota= float(input("ingrese su nota"))
        if nota>=6:
            print(f"APROBADO")
        else:
            print(f"REPROBADO")
        break
    except ValueError:
        print("error, ingrese un numero")
# Out:
# error, ingrese un numero
# REPROBADO

# %% [markdown]
# ### 14. Contraseña Secreta
#
# **Consigna:**
# 1. Define una variable `contrasena_correcta = "python123"`.
# 2. Pide al usuario que ingrese la contraseña.
# 3. Si coincide, imprime **"Acceso concedido"**.
# 4. Si no, imprime **"Contraseña incorrecta"**.

# %%
# Tu código aquí 👇}
while True:
    contra="python123"
    poner= input("ingrese la contraseña")
    if contra==poner :
        print(f"acceso concedido")
        break
    else:
        print(f"contraseña incorrecta")
# Out:
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# contraseña incorrecta
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 5
#       1 # Tu código aquí 👇}
#       2 while True:
#       3
#       4     contra="python123"
# ----> 5     poner= input("ingrese la contraseña")
#       6     if contra==poner :
#       7         print(f"acceso concedido")
#       8         break
#
# File ~/Documentos/ClaseOC/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
# ...

# %% [markdown]
# ### 15. Semáforo
#
# **Consigna:**
# 1. Pide al usuario el color del semáforo (Verde, Amarillo, Rojo).
# 2. Si es "Verde" -> **"Avanzar"**.
# 3. Si es "Amarillo" -> **"Precaución"**.
# 4. Si es "Rojo" -> **"Detenerse"**.

# %%
# Tu código aquí 👇
while True:

    sema= input("ingresa el color del semaforo")
    verde="verde"
    amarillo="amarillo"
    rojo="rojo"
    if sema==verde:
        print("avanzar")
        break
    elif sema==amarillo:
        print("precaucion")
        break
    elif sema==rojo:
        print("pare")
        break
    else:
        print("error, ingrese un argumento valido")
# Out:
# error, ingrese un argumento valido
# error, ingrese un argumento valido
# precaucion

# %% [markdown]
# ### 16. Generador de Nombre de Banda
#
# **Consigna:**
# 1. Pide al usuario el nombre de la **ciudad** donde nació.
# 2. Pide el nombre de su **mascota**.
# 3. Concatena ambos nombres para formar el nombre de su banda de rock.
# 4. Muestra el resultado.

# %%
# Tu código aquí 👇
cn= input("ingrese su ciudad natal")
nm= input("pon el nombre de tu mascota")
print(f"{cn}{nm} BAND")
# Out:
# ALENKATOF BAND

# %% [markdown]
# ### 17. Calculadora de IMC
#
# **Consigna:**
# 1. Pide el **peso** en kg.
# 2. Pide la **altura** en metros.
# 3. Calcula el IMC: `peso / (altura * altura)`.
# 4. Muestra el resultado.

# %%
# Tu código aquí 👇
while True:
    try:
                
        P= float(input("ingrese sun peso"))
        a= float(input("ingrese su altura en metros"))
        imc= P/(a*a)
        print(f"su imc es:{imc}")
        break
    except ValueError:
        print("error, ingrese un numero")
    except ZeroDivisionError:
        print("error no se puede medir 0 cm ")
# Out:
# error, ingrese un numero
# error, ingrese un numero
# error, ingrese un numero
# su imc es:0.2

# %% [markdown]
# ### 18. Número Mágico
#
# **Consigna:**
# 1. Define un **número secreto** en una variable (ej. 7).
# 2. Pide al usuario que adivine el número (entre 1 y 10).
# 3. Si adivina, imprime **"¡Ganaste!"**.
# 4. Si no, imprime **"Intenta de nuevo"**.

# %%
# Tu código aquí 👇
while True:
    nums="6"
    ni=input("ingrese un numero entre 1 y 10")
    if nums==ni :
        print("GANASTE")
        break
    else:
        print("intente de nuevo")
# Out:
# intente de nuevo
# intente de nuevo
# intente de nuevo
# intente de nuevo
# GANASTE

# %% [markdown]
# ### 19. Piedra, Papel o Tijera (Simplificado)
#
# **Consigna:**
# 1. El programa siempre elige **"Piedra"** (guárdalo en una variable).
# 2. Pide al usuario que elija (Piedra, Papel o Tijera).
# 3. Si el usuario elige "Papel", imprime **"¡Ganaste! Papel envuelve a Piedra"**.
# 4. Si elige "Piedra", imprime **"Empate"**.
# 5. Si elige "Tijera", imprime **"Perdiste. Piedra rompe Tijera"**.

# %%
# Tu código aquí 👇
while True:
    mp="piedra"
    s=input("ingrese piedra, papel o tijera")
    piedra="piedra"
    papel="papel"
    tijera="tijera"
    if s== papel :
        print("ganaste")
        break
    elif s==piedra :
        print("empate")
        break
    elif s==tijera :
        print("perdiste")
        break
    else:
        print("error,ingrese un argumento valido")

# %% [markdown]
# ### 20. Bienvenida Personalizada
#
# **Consigna:**
# 1. Pide el **nombre** del usuario.
# 2. Pide su **ciudad** de origen.
# 3. Imprime un mensaje amigable: **"Hola [Nombre], bienvenido a [Ciudad]. ¡Espero que disfrutes el curso!"**

# %%
# Tu código aquí 👇
c= input("ingrese su ciudad")
n= input("ingrese su nombre")
print(f"hola {n}, bienvenido a {c}, disfruta tu curso")
# Out:
# hola tofu, bienvenido a tof
